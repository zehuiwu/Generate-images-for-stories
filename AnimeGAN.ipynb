# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/AnimeGAN
# Out:
# /content/drive/MyDrive/AnimeGAN

# %%
# !pip install onnxruntime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 25.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.4 MB/s eta 0:00:00
# ...

# %%
# !python deploy/test_by_onnx.py -i inputs/imgs/ -o output/results -m deploy/AnimeGANv3_Shinkai_37.onnx
# Out:
# Processing image: 0, image size: (1202, 669), inputs/imgs/Low_Library_NYC_skyline_night_lights.jpg  time: 5.361 s
# Processing image: 1, image size: (1200, 800), inputs/imgs/New_york_times_square-terabass.jpg  time: 7.201 s
# Processing image: 2, image size: (800, 450), inputs/imgs/View_of_Empire_State_Building_from_Rockefeller_Center_New_York_City_dllu_(cropped).jpg  time: 2.224 s
# Processing image: 3, image size: (2190, 1369), inputs/imgs/106268734-1574876711571gettyimages-1059614218.jpeg  time: 21.136 s
# Processing image: 4, image size: (600, 400), inputs/imgs/85.jpeg  time: 2.066 s
# Processing image: 5, image size: (1024, 600), inputs/imgs/fuji-cherry-GettyImages-1060517676-1024x600.jpeg  time: 4.121 s
# Processing image: 6, image size: (1920, 1280), inputs/imgs/what-is-japan-known-for-mt-fuji-hero.jpg  time: 16.900 s
# Processing image: 7, image size: (1920, 1080), inputs/imgs/1710795602070_e0b48d8c-087c-4220-b368-1047fc7dee76.jpg  time: 14.174 s
# ...
